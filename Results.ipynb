# %% [markdown]
# ## check GPU availabilty

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Number of GPUs Available: ", len(physical_devices))
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Number of GPUs Available:  1

# %% [markdown]
# ## Paths

# %%
CUR_DIR = '/content/' #this may be different runnig local
MAT_DIR= CUR_DIR+'mat/'
TRAIN_MAT_PATH = MAT_DIR + 'train/train/'
TEST_MAT_PATH = MAT_DIR + 'test/test/'
VOICE_DIR = CUR_DIR+'voice/'
TRAIN_VOICE_PATH = VOICE_DIR+'train/train/'
TEST_VOICE_PATH = VOICE_DIR+'test/test/'
DRIVE_PATH = CUR_DIR+'drive/MyDrive/Bachelor_Project/'
DRIVE2_PATH = CUR_DIR+'drive/MyDrive/Bachelor_Project_Part2/'
DRIVE3_PATH = CUR_DIR+'drive/MyDrive/Bachelor_Project_Part3/'
#TRAIN_VOICE_OLD_PATH = CUR_DIR+'train/train/'
#TEST_VOICE_OLD_PATH = CUR_DIR+'test/test/'
#TRAIN_IMG_PATH = CUR_DIR+'train/train-img/'
#TEST_IMG_PATH = CUR_DIR+'test/test-img/'
TRAIN_MAT_PATH = MAT_DIR + 'train/'
TEST_MAT_PATH = MAT_DIR + 'test/'
MOZILLA_PATH= CUR_DIR+'mozilla/'
MOZILLA_VALID_TRAIN = CUR_DIR+'mozilla/cv-valid-train/'
MOZILLA_VALID_DEV = CUR_DIR+'mozilla/cv-valid-dev/'
MOZILLA_VALID_TEST = CUR_DIR+'mozilla/cv-valid-test/'
SHEMO_DF = DRIVE_PATH + 'shemo/'
SHEMO_VOICE = VOICE_DIR + 'shemo/'
FINAL_DF = DRIVE_PATH + 'finaldf/'

# %%
! mkdir $MAT_DIR
! mkdir $VOICE_DIR
! mkdir $TRAIN_MAT_PATH
! mkdir $TEST_MAT_PATH

# %% [markdown]
# ## mount google drive

# %%
from google.colab import drive
drive.mount(CUR_DIR+'drive/', force_remount=True)
#%cd '{CUR_DIR}drive/MyDrive/Bachelor_Project/'
#%ls
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

from glob import glob
import librosa
import librosa.display
import soundfile as sf
import scipy.signal as signal
import gc
import shutil

# %% [markdown]
# ## spoken-language-identification dataset

# %%
! mkdir ~/.kaggle
! cp $DRIVE_PATH/kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download toponowicz/spoken-language-identification
# Out:
# Downloading spoken-language-identification.zip to /content
# 100% 14.9G/14.9G [03:23<00:00, 80.8MB/s]
# 100% 14.9G/14.9G [03:23<00:00, 78.9MB/s]

# %%
# %%capture
# !unzip {CUR_DIR}spoken-language-identification.zip -d $VOICE_DIR

# %%
# !rm {CUR_DIR}spoken-language-identification.zip

# %%
test_data_dir=np.array(glob(TEST_VOICE_PATH+"*"))
testdf = pd.DataFrame(test_data_dir,columns = ['file'])
format_len = len('flac')
testdf['ID']= testdf['file'].apply(lambda x: x.split('/')[-1][:-format_len]+'npy')
testdf
# Out:
#                                                   file  \
# 0    /content/voice/test/test/de_m_923551d571cc4373...
# 1    /content/voice/test/test/en_m_b74b2bf2af570393...
# 2    /content/voice/test/test/de_f_63f5b79c76cf5a1a...
# 3    /content/voice/test/test/en_f_67a0cba10d171b24...
# 4    /content/voice/test/test/de_m_923551d571cc4373...
# ..                                                 ...
# 535  /content/voice/test/test/de_f_63f5b79c76cf5a1a...
# 536  /content/voice/test/test/es_m_08111ce8d6a7ebc6...
# 537  /content/voice/test/test/de_m_923551d571cc4373...
# 538  /content/voice/test/test/de_m_923551d571cc4373...
# 539  /content/voice/test/test/en_f_67a0cba10d171b24...
#
#                                                     ID
# 0    de_m_923551d571cc437382d0294dda2dd0aa.fragment...
# 1    en_m_b74b2bf2af570393cae91f4ed89cece7.fragment...
# 2    de_f_63f5b79c76cf5a1a4bbd1c40f54b166e.fragment...
# 3    en_f_67a0cba10d171b24039a79faa1d4d603.fragment...
# 4    de_m_923551d571cc437382d0294dda2dd0aa.fragment...
# ..                                                 ...
# 535  de_f_63f5b79c76cf5a1a4bbd1c40f54b166e.fragment...
# 536  es_m_08111ce8d6a7ebc6cd2c27e62a3d98f0.fragment...
# 537  de_m_923551d571cc437382d0294dda2dd0aa.fragment...
# 538  de_m_923551d571cc437382d0294dda2dd0aa.fragment...
# 539  en_f_67a0cba10d171b24039a79faa1d4d603.fragment...
#
# [540 rows x 2 columns]

# %%
traindf['lang'] = traindf['ID'].apply(lambda x: x.split('_')[0])
testdf['lang'] = testdf['ID'].apply(lambda x: x.split('_')[0])

# %% [markdown]
# ##

# %% [markdown]
# ## Shemo dataset

# %%
! mkdir $SHEMO_VOICE

# %%
# !wget -O male.zip "https://www.dropbox.com/s/xfi3hi927yxixa9/male.zip?dl=0"
# Out:
# --2023-08-25 08:19:35--  https://www.dropbox.com/s/xfi3hi927yxixa9/male.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/xfi3hi927yxixa9/male.zip [following]
# --2023-08-25 08:19:35--  https://www.dropbox.com/s/raw/xfi3hi927yxixa9/male.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uceea4a303c16cdf443bda9d0233.dl.dropboxusercontent.com/cd/0/inline/CCc7fmX0uXrSQxxAq9g9BUhTNI-TU2HE73CyxutieHFwPbJYknD8PYv4sm21qjb4GC0PcC1UGG7F-ez0hp5874hgzgElCG2TeMwy_f_1Ep0m98xaBxxYKmM0BLDFI-CZ5uwc0ecvLprAMnT9zad0p13V/file# [following]
# --2023-08-25 08:19:35--  https://uceea4a303c16cdf443bda9d0233.dl.dropboxusercontent.com/cd/0/inline/CCc7fmX0uXrSQxxAq9g9BUhTNI-TU2HE73CyxutieHFwPbJYknD8PYv4sm21qjb4GC0PcC1UGG7F-ez0hp5874hgzgElCG2TeMwy_f_1Ep0m98xaBxxYKmM0BLDFI-CZ5uwc0ecvLprAMnT9zad0p13V/file
# Resolving uceea4a303c16cdf443bda9d0233.dl.dropboxusercontent.com (uceea4a303c16cdf443bda9d0233.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to uceea4a303c16cdf443bda9d0233.dl.dropboxusercontent.com (uceea4a303c16cdf443bda9d0233.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CCdSCgilFYUuvdPaKQq0gIbqiAx9qdRF-st6EkwC1o8AXLgBwlqVtoPcWHB_OSw9P0TUEb9ieynjzHo6gF9AmWQjoFIrhYfhLZ_ALYuC97q33fGUcWinGNjbS4yoZEM2pCk9ztAwliF_fbsQy00_O5KuweSZpOvR3NkY-PN8SM59YcOthW5VMLA-gYXUG7fs8MGNKFr-7-KyrcTkjFmE06P34l-r39HfsJPOk2qCwDoSCo4Jqg4zCJyb6oP1BrBOOgROOsKFRDpdwBTLJafT8XH15hYAxvjtK_Z4aj2rdHjB65e0mwuSOEUtbqkd15nof_PibYyQHTEpXx_t6uCwUMqSI9WjcWHVS0eNwHHK561_XJ31BFOamOdfIf3G_eJXKPk/file [following]
# --2023-08-25 08:19:36--  https://uceea4a303c16cdf443bda9d0233.dl.dropboxusercontent.com/cd/0/inline2/CCdSCgilFYUuvdPaKQq0gIbqiAx9qdRF-st6EkwC1o8AXLgBwlqVtoPcWHB_OSw9P0TUEb9ieynjzHo6gF9AmWQjoFIrhYfhLZ_ALYuC97q33fGUcWinGNjbS4yoZEM2pCk9ztAwliF_fbsQy00_O5KuweSZpOvR3NkY-PN8SM59YcOthW5VMLA-gYXUG7fs8MGNKFr-7-KyrcTkjFmE06P34l-r39HfsJPOk2qCwDoSCo4Jqg4zCJyb6oP1BrBOOgROOsKFRDpdwBTLJafT8XH15hYAxvjtK_Z4aj2rdHjB65e0mwuSOEUtbqkd15nof_PibYyQHTEpXx_t6uCwUMqSI9WjcWHVS0eNwHHK561_XJ31BFOamOdfIf3G_eJXKPk/file
# Reusing existing connection to uceea4a303c16cdf443bda9d0233.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 496623909 (474M) [application/zip]
# Saving to: ‘male.zip’
#
# male.zip            100%[===================>] 473.62M  22.1MB/s    in 22s
#
# 2023-08-25 08:19:58 (21.8 MB/s) - ‘male.zip’ saved [496623909/496623909]

# %%
# !wget -O female.zip "https://www.dropbox.com/s/4t6mep8mo4yf81f/female.zip?dl=0"
# Out:
# --2023-08-25 08:19:58--  https://www.dropbox.com/s/4t6mep8mo4yf81f/female.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/4t6mep8mo4yf81f/female.zip [following]
# --2023-08-25 08:19:58--  https://www.dropbox.com/s/raw/4t6mep8mo4yf81f/female.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc15f585881e4b25150a613854d5.dl.dropboxusercontent.com/cd/0/inline/CCe2e3pxEVHLZz7iI06Pmtge_SXbdNJvmOUeSDPSLxPHEmN83BAqeYiC2cnFAa_4NObBneUl1njgEtRPRp7AHLw_TA5i7wm7w800o-KrfdlqAMBhHGjREWxkI5za8Dq1iCfBTpK87SMvKV4b851tQ_LX/file# [following]
# --2023-08-25 08:19:59--  https://uc15f585881e4b25150a613854d5.dl.dropboxusercontent.com/cd/0/inline/CCe2e3pxEVHLZz7iI06Pmtge_SXbdNJvmOUeSDPSLxPHEmN83BAqeYiC2cnFAa_4NObBneUl1njgEtRPRp7AHLw_TA5i7wm7w800o-KrfdlqAMBhHGjREWxkI5za8Dq1iCfBTpK87SMvKV4b851tQ_LX/file
# Resolving uc15f585881e4b25150a613854d5.dl.dropboxusercontent.com (uc15f585881e4b25150a613854d5.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6021:15::a27d:410f
# Connecting to uc15f585881e4b25150a613854d5.dl.dropboxusercontent.com (uc15f585881e4b25150a613854d5.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CCe7vmc39dbeaBRreQPK_RCrMuu1Wa2GM157llRk45UNXrihbKWoVJGDUP46JV-f65-ut2a0exY4u7w_N4mmuaAyvZ94I-SvLjYEPiOhEdzZq6S3vDAOWNkNTggkIZgho0gAZY1nxQ5BThGgWD_1oK8WZQFm_hKHcgPjY19Jbn8IlyPZ3q0cVEuTFuSpv1FUQe8qQrXQJkKlZZENmYt4mMdaI6bDrO66p7J1WTTzQBWaRbp4FxQpwDW-XlukCQ4aRQl3txIf2kJ--uhmy4i6GowL7n8IMl5GWPtniktQaiEXJ0V37X71GHNuTzUHsEcnNv6ClIeihDiyiYkVicudYD6k0vxF4w6HxZrmKZaKRxm_H-HdGXL6pbco-LM4ZzSHLNw/file [following]
# --2023-08-25 08:19:59--  https://uc15f585881e4b25150a613854d5.dl.dropboxusercontent.com/cd/0/inline2/CCe7vmc39dbeaBRreQPK_RCrMuu1Wa2GM157llRk45UNXrihbKWoVJGDUP46JV-f65-ut2a0exY4u7w_N4mmuaAyvZ94I-SvLjYEPiOhEdzZq6S3vDAOWNkNTggkIZgho0gAZY1nxQ5BThGgWD_1oK8WZQFm_hKHcgPjY19Jbn8IlyPZ3q0cVEuTFuSpv1FUQe8qQrXQJkKlZZENmYt4mMdaI6bDrO66p7J1WTTzQBWaRbp4FxQpwDW-XlukCQ4aRQl3txIf2kJ--uhmy4i6GowL7n8IMl5GWPtniktQaiEXJ0V37X71GHNuTzUHsEcnNv6ClIeihDiyiYkVicudYD6k0vxF4w6HxZrmKZaKRxm_H-HdGXL6pbco-LM4ZzSHLNw/file
# Reusing existing connection to uc15f585881e4b25150a613854d5.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 374386654 (357M) [application/zip]
# Saving to: ‘female.zip’
#
# female.zip          100%[===================>] 357.04M  18.5MB/s    in 17s
#
# 2023-08-25 08:20:17 (21.2 MB/s) - ‘female.zip’ saved [374386654/374386654]

# %%
# %%capture
# !unzip {CUR_DIR}male.zip -d $VOICE_DIR
# !unzip {CUR_DIR}female.zip -d $VOICE_DIR

# %%
# !rm {CUR_DIR}male.zip
# !rm {CUR_DIR}female.zip

# %%
! mv $VOICE_DIR/male/* $SHEMO_VOICE
! mv $VOICE_DIR/female/* $SHEMO_VOICE

# %%
shemo_train_df = pd.read_csv(SHEMO_DF+"train.csv")
shemo_validation_df = pd.read_csv(SHEMO_DF+"validation.csv")
shemo_test_df = pd.read_csv(SHEMO_DF+"test.csv")

# %%
format_len = len('wav')
shemo_train_df['name'] = shemo_train_df['file']
shemo_train_df['file'] = shemo_train_df['file'].apply(lambda x: TRAIN_VOICE_PATH+x)
shemo_train_df['ID'] = shemo_train_df['file'].apply(lambda x: x.split('/')[-1][:-format_len]+'npy')
shemo_train_df['lang'] = 'fa'

# %%
format_len = len('wav')
shemo_validation_df['name'] = shemo_validation_df['file']
shemo_validation_df['file'] = shemo_validation_df['file'].apply(lambda x: TRAIN_VOICE_PATH+x)
shemo_validation_df['ID'] = shemo_validation_df['file'].apply(lambda x: x.split('/')[-1][:-format_len]+'npy')
shemo_validation_df['lang'] = 'fa'

# %%
format_len = len('wav')
shemo_test_df['name'] = shemo_test_df['file']
shemo_test_df['file'] = shemo_test_df['file'].apply(lambda x: TEST_VOICE_PATH+x)
shemo_test_df['ID'] = shemo_test_df['file'].apply(lambda x: x.split('/')[-1][:-format_len]+'npy')
shemo_test_df['lang'] = 'fa'

# %%
def move_shemo(name, save_prefix):
    y, sr = librosa.load(SHEMO_VOICE+name, sr=None)
    current_duration = librosa.get_duration(y=y, sr=sr)

    if current_duration >= 10:
        shutil.move(SHEMO_VOICE+name, save_prefix+name)

    silence_duration = 10 - current_duration
    silence_samples = int(silence_duration * sr)
    silence = np.zeros(silence_samples)
    new_audio = np.concatenate((y, silence), axis=0)
    sf.write(save_prefix+name, new_audio, sr)

# %%
np.vectorize(move_shemo)(shemo_train_df['name'], TRAIN_VOICE_PATH)
np.vectorize(move_shemo)(shemo_validation_df['name'], TRAIN_VOICE_PATH)
np.vectorize(move_shemo)(shemo_test_df['name'], TEST_VOICE_PATH)

# %%
keep_shemo_col = ['ID','file','lang']
shemo_train_df = shemo_train_df[keep_shemo_col]
shemo_validation_df = shemo_validation_df[keep_shemo_col]
shemo_test_df = shemo_test_df[keep_shemo_col]

# %%
shemo_train_df
# Out:
#               ID                                   file lang
# 0     M27N31.npy  /content/voice/train/train/M27N31.wav   fa
# 1     M46A05.npy  /content/voice/train/train/M46A05.wav   fa
# 2     M05S11.npy  /content/voice/train/train/M05S11.wav   fa
# 3     F21S25.npy  /content/voice/train/train/F21S25.wav   fa
# 4     F28A08.npy  /content/voice/train/train/F28A08.wav   fa
# ...          ...                                    ...  ...
# 1926  M19A01.npy  /content/voice/train/train/M19A01.wav   fa
# 1927  F26N04.npy  /content/voice/train/train/F26N04.wav   fa
# 1928  M37S01.npy  /content/voice/train/train/M37S01.wav   fa
# 1929  F09H02.npy  /content/voice/train/train/F09H02.wav   fa
# 1930  F01W05.npy  /content/voice/train/train/F01W05.wav   fa
#
# [1931 rows x 3 columns]

# %%
shemo_validation_df
# Out:
#              ID                                   file lang
# 0    F20W04.npy  /content/voice/train/train/F20W04.wav   fa
# 1    M25A24.npy  /content/voice/train/train/M25A24.wav   fa
# 2    F31A02.npy  /content/voice/train/train/F31A02.wav   fa
# 3    M25N06.npy  /content/voice/train/train/M25N06.wav   fa
# 4    M25N21.npy  /content/voice/train/train/M25N21.wav   fa
# ..          ...                                    ...  ...
# 273  M17H01.npy  /content/voice/train/train/M17H01.wav   fa
# 274  M25N09.npy  /content/voice/train/train/M25N09.wav   fa
# 275  F02N04.npy  /content/voice/train/train/F02N04.wav   fa
# 276  M25A60.npy  /content/voice/train/train/M25A60.wav   fa
# 277  F02W03.npy  /content/voice/train/train/F02W03.wav   fa
#
# [278 rows x 3 columns]

# %%
shemo_test_df
# Out:
#              ID                                 file lang
# 0    M26N01.npy  /content/voice/test/test/M26N01.wav   fa
# 1    F11S01.npy  /content/voice/test/test/F11S01.wav   fa
# 2    M12N68.npy  /content/voice/test/test/M12N68.wav   fa
# 3    F07A27.npy  /content/voice/test/test/F07A27.wav   fa
# 4    M12A37.npy  /content/voice/test/test/M12A37.wav   fa
# ..          ...                                  ...  ...
# 465  M47N02.npy  /content/voice/test/test/M47N02.wav   fa
# 466  M12A54.npy  /content/voice/test/test/M12A54.wav   fa
# 467  F07A36.npy  /content/voice/test/test/F07A36.wav   fa
# 468  M12A31.npy  /content/voice/test/test/M12A31.wav   fa
# 469  F07A12.npy  /content/voice/test/test/F07A12.wav   fa
#
# [470 rows x 3 columns]

# %% [markdown]
# ### create folders

# %%
! mkdir $CUR_DIR/train
! mkdir $CUR_DIR/test

# %%
! mv $TRAIN_VOICE_PATH $TRAIN_VOICE_OLD_PATH
! mv $TEST_VOICE_PATH $TEST_VOICE_OLD_PATH

# %%
# !mkdir $TRAIN_IMG_PATH
# !mkdir $TEST_IMG_PATH
# Out:
# mkdir: missing operand
# Try 'mkdir --help' for more information.
# mkdir: missing operand
# Try 'mkdir --help' for more information.

# %% [markdown]
# ## Create spectogram

# %%
def spectrogram_mat(address_prefix, file, save_prefix, format='flac'):
    clip, sample_rate = librosa.load(address_prefix+file[:-3]+format, sr=22050)
    S = librosa.feature.melspectrogram(y=clip, sr=sample_rate)#, n_mels=40, hop_length=221) ##
    SP = librosa.power_to_db(S, ref=np.max)
    np.save(save_prefix+file, SP)

# %% [markdown]
# #### shemo

# %%
# %%time
format_len = len('wav')
np.vectorize(spectrogram_mat)(TEST_VOICE_PATH, shemo_test_df['ID'], TEST_MAT_PATH, format='wav')
shemo_test_df
# Out:
# CPU times: user 14.7 s, sys: 10.7 s, total: 25.5 s
# Wall time: 15.7 s
#              ID                                 file lang
# 0    M26N01.npy  /content/voice/test/test/M26N01.wav   fa
# 1    F11S01.npy  /content/voice/test/test/F11S01.wav   fa
# 2    M12N68.npy  /content/voice/test/test/M12N68.wav   fa
# 3    F07A27.npy  /content/voice/test/test/F07A27.wav   fa
# 4    M12A37.npy  /content/voice/test/test/M12A37.wav   fa
# ..          ...                                  ...  ...
# 465  M47N02.npy  /content/voice/test/test/M47N02.wav   fa
# 466  M12A54.npy  /content/voice/test/test/M12A54.wav   fa
# 467  F07A36.npy  /content/voice/test/test/F07A36.wav   fa
# 468  M12A31.npy  /content/voice/test/test/M12A31.wav   fa
# 469  F07A12.npy  /content/voice/test/test/F07A12.wav   fa
#
# [470 rows x 3 columns]

# %% [markdown]
# #### spoken language identification

# %%
# %%time
format_len = len('flac')
np.vectorize(spectrogram_mat)(TEST_VOICE_PATH, testdf['ID'], TEST_MAT_PATH)
testdf
# Out:
# CPU times: user 31.7 s, sys: 17 s, total: 48.7 s
# Wall time: 36.8 s
#                                                   file  \
# 0    /content/voice/test/test/de_m_923551d571cc4373...
# 1    /content/voice/test/test/en_m_b74b2bf2af570393...
# 2    /content/voice/test/test/de_f_63f5b79c76cf5a1a...
# 3    /content/voice/test/test/en_f_67a0cba10d171b24...
# 4    /content/voice/test/test/de_m_923551d571cc4373...
# ..                                                 ...
# 535  /content/voice/test/test/de_f_63f5b79c76cf5a1a...
# 536  /content/voice/test/test/es_m_08111ce8d6a7ebc6...
# 537  /content/voice/test/test/de_m_923551d571cc4373...
# 538  /content/voice/test/test/de_m_923551d571cc4373...
# 539  /content/voice/test/test/en_f_67a0cba10d171b24...
#
#                                                     ID lang
# 0    de_m_923551d571cc437382d0294dda2dd0aa.fragment...   de
# 1    en_m_b74b2bf2af570393cae91f4ed89cece7.fragment...   en
# 2    de_f_63f5b79c76cf5a1a4bbd1c40f54b166e.fragment...   de
# 3    en_f_67a0cba10d171b24039a79faa1d4d603.fragment...   en
# 4    de_m_923551d571cc437382d0294dda2dd0aa.fragment...   de
# ..                                                 ...  ...
# 535  de_f_63f5b79c76cf5a1a4bbd1c40f54b166e.fragment...   de
# 536  es_m_08111ce8d6a7ebc6cd2c27e62a3d98f0.fragment...   es
# 537  de_m_923551d571cc437382d0294dda2dd0aa.fragment...   de
# 538  de_m_923551d571cc437382d0294dda2dd0aa.fragment...   de
# 539  en_f_67a0cba10d171b24039a79faa1d4d603.fragment...   en
#
# [540 rows x 3 columns]

# %%
gc.collect()
# Out:
# 106810

# %%
# !rm {CUR_DIR}spoken-language-identification.zip

# %%
# !rm $VOICE_DIR -r

# %% [markdown]
# ## Data Generator

# %%
from tensorflow import keras
import numpy as np
import os

class NumpyDataGenerator(keras.utils.Sequence):
    def __init__(self, data_folder, ids, labels, batch_size, shuffle=True, seed=None, rescale=None, subset='training'):
        self.data_folder = data_folder
        ## changed:
        #self.ids = ids
        self.file_list = ids
        #self.labels = labels
        self.file_labels = labels

        self.batch_size = batch_size
        #self.validation_split = validation_split
        self.shuffle = shuffle
        self.seed = seed
        self.rescale = rescale
        self.subset = subset

        #self._split_data()

        if self.shuffle:
            self._shuffle_data()


    def _shuffle_data(self):
        if self.seed is not None:
            np.random.seed(self.seed)
        indices = np.random.permutation(len(self.file_list))
        self.file_list = self.file_list[indices]
        self.file_labels = self.file_labels[indices]


    def __len__(self):
        return len(self.file_list) // self.batch_size

    def __getitem__(self, idx):
        r = (idx + 1) * self.batch_size
        if r > len(self.file_list):
            r = len(self.file_list)
        batch_files = self.file_list[idx * self.batch_size: r]
        batch_labels = self.file_labels[idx * self.batch_size: r]

        batch_data = np.empty((len(batch_files), *(128, 431))) #(40, 998)
        for i, filename in enumerate(batch_files):
            batch_data[i,] = np.load(os.path.join(self.data_folder, filename))
            #batch_data[i,] = self._create_spectrogram(self.data_folder, filename)
            #batch_data[i,] = self._create_spectrogram(os.path.join(self.data_folder, filename[:-3]+'flac'))

        return batch_data, batch_labels

    def on_epoch_end(self, logs=None):
        if self.shuffle:
            self._shuffle_data()

# %%
### in case tesdf df is ruined
testdf = pd.read_csv(DRIVE_PATH+'testdf.csv')
testdf.drop('Unnamed: 0', axis=1, inplace=True)
testdf
###
# Out:
#                                                   file  \
# 0    /content/voice/test/test/en_f_67a0cba10d171b24...
# 1    /content/voice/test/test/en_m_b74b2bf2af570393...
# 2    /content/voice/test/test/es_f_50298ab71aaba850...
# 3    /content/voice/test/test/de_f_63f5b79c76cf5a1a...
# 4    /content/voice/test/test/en_f_67a0cba10d171b24...
# ..                                                 ...
# 535  /content/voice/test/test/de_m_923551d571cc4373...
# 536  /content/voice/test/test/en_m_b74b2bf2af570393...
# 537  /content/voice/test/test/en_m_b74b2bf2af570393...
# 538  /content/voice/test/test/de_m_923551d571cc4373...
# 539  /content/voice/test/test/de_m_923551d571cc4373...
#
#                                                     ID lang
# 0    en_f_67a0cba10d171b24039a79faa1d4d603.fragment...   en
# 1    en_m_b74b2bf2af570393cae91f4ed89cece7.fragment...   en
# 2    es_f_50298ab71aaba8508ebeef49d853df11.fragment...   es
# 3    de_f_63f5b79c76cf5a1a4bbd1c40f54b166e.fragment...   de
# 4    en_f_67a0cba10d171b24039a79faa1d4d603.fragment...   en
# ..                                                 ...  ...
# 535  de_m_923551d571cc437382d0294dda2dd0aa.fragment...   de
# 536  en_m_b74b2bf2af570393cae91f4ed89cece7.fragment...   en
# 537  en_m_b74b2bf2af570393cae91f4ed89cece7.fragment...   en
# 538  de_m_923551d571cc437382d0294dda2dd0aa.fragment...   de
# 539  de_m_923551d571cc437382d0294dda2dd0aa.fragment...   de
#
# [540 rows x 3 columns]

# %%
shemo_test_df
# Out:
#              ID                                 file lang
# 0    M26N01.npy  /content/voice/test/test/M26N01.wav   fa
# 1    F11S01.npy  /content/voice/test/test/F11S01.wav   fa
# 2    M12N68.npy  /content/voice/test/test/M12N68.wav   fa
# 3    F07A27.npy  /content/voice/test/test/F07A27.wav   fa
# 4    M12A37.npy  /content/voice/test/test/M12A37.wav   fa
# ..          ...                                  ...  ...
# 465  M47N02.npy  /content/voice/test/test/M47N02.wav   fa
# 466  M12A54.npy  /content/voice/test/test/M12A54.wav   fa
# 467  F07A36.npy  /content/voice/test/test/F07A36.wav   fa
# 468  M12A31.npy  /content/voice/test/test/M12A31.wav   fa
# 469  F07A12.npy  /content/voice/test/test/F07A12.wav   fa
#
# [470 rows x 3 columns]

# %%
### concat test
testdf = pd.concat([testdf, shemo_test_df.iloc[:180]], axis=0)

# %%
testdf
# Out:
#                                                   file  \
# 0    /content/voice/test/test/en_f_67a0cba10d171b24...
# 1    /content/voice/test/test/en_m_b74b2bf2af570393...
# 2    /content/voice/test/test/es_f_50298ab71aaba850...
# 3    /content/voice/test/test/de_f_63f5b79c76cf5a1a...
# 4    /content/voice/test/test/en_f_67a0cba10d171b24...
# ..                                                 ...
# 175                /content/voice/test/test/F22S13.wav
# 176                /content/voice/test/test/M26A04.wav
# 177                /content/voice/test/test/F22S02.wav
# 178                /content/voice/test/test/M26S05.wav
# 179                /content/voice/test/test/M12N77.wav
#
#                                                     ID lang
# 0    en_f_67a0cba10d171b24039a79faa1d4d603.fragment...   en
# 1    en_m_b74b2bf2af570393cae91f4ed89cece7.fragment...   en
# 2    es_f_50298ab71aaba8508ebeef49d853df11.fragment...   es
# 3    de_f_63f5b79c76cf5a1a4bbd1c40f54b166e.fragment...   de
# 4    en_f_67a0cba10d171b24039a79faa1d4d603.fragment...   en
# ..                                                 ...  ...
# 175                                         F22S13.npy   fa
# 176                                         M26A04.npy   fa
# 177                                         F22S02.npy   fa
# 178                                         M26S05.npy   fa
# 179                                         M12N77.npy   fa
#
# [720 rows x 3 columns]

# %%
### test encoder
X_testid = np.array(testdf['ID'].values)
y_test = np.array(testdf['lang'].values)

from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

label_encoder = LabelEncoder()
y_test = label_encoder.fit_transform(y_test)
y_test = to_categorical(y_test, 4)

# %%
# train encoder from test
X_trainid = np.array(traindf['ID'].values)
y_train = np.array(traindf['lang'].values)

y_train = label_encoder.transform(y_train)
y_train = to_categorical(y_train, 4)

# %%
traindf
# Out:
#                                                     file  \
# 0      /content/voice/train/train/es_m_f16e9da2ba7126...
# 1      /content/voice/train/train/es_m_b8e0e6f56f02e6...
# 2      /content/voice/train/train/de_m_502293f2297515...
# 3      /content/voice/train/train/en_m_81995ee8a5e990...
# 4      /content/voice/train/train/en_f_9a47e3d56398b8...
# ...                                                  ...
# 73075  /content/voice/train/train/de_m_4d099776261f22...
# 73076  /content/voice/train/train/en_f_058b70233667e1...
# 73077  /content/voice/train/train/es_m_768526f634547e...
# 73078  /content/voice/train/train/de_m_fc6bd6bb9d66a8...
# 73079  /content/voice/train/train/es_m_f7d959494477e5...
#
#                                                       ID lang
# 0      es_m_f16e9da2ba7126292cb4e46ce16995bc.fragment...   es
# 1      es_m_b8e0e6f56f02e6f8f79cc360958e5982.fragment...   es
# 2      de_m_502293f229751563d1768dd2367a6b29.fragment...   de
# 3      en_m_81995ee8a5e990193b7858ec4b158e48.fragment...   en
# 4      en_f_9a47e3d56398b8108f59385aab8bbe87.fragment...   en
# ...                                                  ...  ...
# 73075  de_m_4d099776261f2267d3148a7e7e766d14.fragment...   de
# 73076  en_f_058b70233667e1b64506dddf9f9d6b46.fragment...   en
# 73077  es_m_768526f634547e2b45fd84556ecd70f6.fragment...   es
# 73078  de_m_fc6bd6bb9d66a89bb8d8a8a7efa23e6b.fragment...   de
# 73079  es_m_f7d959494477e5e7e33d4666f15311c9.fragment...   es
#
# [73080 rows x 3 columns]

# %% [markdown]
# ### define generators

# %%
### test encoder
X_testid = np.array(testdf['ID'].values)
y_test = np.array(testdf['lang'].values)

from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

label_encoder = LabelEncoder()
y_test = label_encoder.fit_transform(y_test)
y_test = to_categorical(y_test, 3)

# %%
test_data_folder = TEST_MAT_PATH #########
batch_size = 1 #1 to cover all!
#validation_split = 0.2
rescale_factor = 1.0 / 255.0

test_params = {
    'data_folder': test_data_folder,
    ##'ids' : X_testid,
    ##'labels': y_test,
    'batch_size': batch_size,
    #'validation_split': validation_split,
    'shuffle': False, #############################
    'seed': 42,
    'rescale': rescale_factor,
}

test_generator = NumpyDataGenerator(subset='test', ids= X_testid, labels= y_test, **test_params)

# %% [markdown]
# ### CRNN model

# %%
import keras
model = tf.keras.saving.load_model(DRIVE_PATH+"models/"+'CRNN_final_15epoch.h5')

# %%
model.evaluate(test_generator, steps= len(test_generator))
# Out:
# 720/720 [==============================] - 10s 13ms/step - loss: 0.3550 - accuracy: 0.8917
# [0.3550313413143158, 0.8916666507720947]

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np


def show_confusion(cur_model):
  y_pred= cur_model.predict(test_generator, steps= len(test_generator))
  y_pred = np.argmax(y_pred, axis=1)
  y_true = test_generator.file_labels[:len(test_generator)*batch_size]
  y_true = np.argmax(y_true, axis=1)
  labels = list(label_encoder.classes_)
  cm = confusion_matrix(y_true, y_pred)

  disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
  disp.plot(cmap=plt.cm.Blues)
  plt.show()

# %%
show_confusion(model)
# Out:
# 720/720 [==============================] - 8s 11ms/step

# %%
print(model.history.history)
# Out:
# {}

# %%
history = {
    'loss' : [0.8661,0.4459,0.2446,0.1553,0.1172,0.0981,0.0766,0.0662,0.0558,0.0561,0.0539,0.0510,0.0485,0.0452,0.0397,],
    'val_loss' : [1.0861,0.4264,0.9657,0.3852,0.3165,0.1170,0.0872,0.1162,0.0721,0.1256,0.1350,0.1267,0.1213,0.2645,0.0545,],
    'accuracy' : [0.5919,0.8331,0.9156,0.9476,0.9614,0.9667,0.9747,0.9781,0.9820,0.9814,0.9814,0.9821,0.9833,0.9845,0.9858,],
    'val_accuracy' :[0.5766,0.8338,0.6865,0.8553,0.8756,0.9599,0.9708,0.9599,0.9755,0.9551,0.9499,0.9566,0.9541,0.9131,0.9815,],
}

# %%
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### results

# %%
import keras
model = tf.keras.saving.load_model(DRIVE_PATH+"models/"+'without_dropout_40epoch_day2.h5')

# %%
model.evaluate(test_generator, steps= len(test_generator))
# Out:
# 540/540 [==============================] - 11s 5ms/step - loss: 0.7143 - accuracy: 0.9630
# [0.7142735123634338, 0.9629629850387573]

# %%
show_confusion(model)
# Out:
# 540/540 [==============================] - 2s 3ms/step

# %%
print(model.history.history)
# Out:
# {}

# %%
history = {
    'loss' : [0.4153,0.0926,0.0504,0.0472,0.0337,0.0279,0.0245,0.0180,0.0207,0.0195,0.0137,0.0224,0.0107,0.0084,0.0124,0.0102,0.0090,0.0102,0.0082,0.0074,0.0076,0.0090,0.0051,0.0075,0.0067,0.0045,0.0069,0.0061,0.0037,0.0053,0.0052,0.0020,0.0051,0.0042,0.0126,0.0046,0.0029,0.0040,0.0059,0.0032,],
    'accuracy' : [0.8352,0.9670,0.9826,0.9833,0.9884,0.9902,0.9916,0.9937,0.9929,0.9935,0.9957,0.9926,0.9964,0.9970,0.9962,0.9965,0.9966,0.9967,0.9975,0.9974,0.9974,0.9971,0.9984,0.9976,0.9978,0.9983,0.9980,0.9981,0.9987,0.9982,0.9985,0.9993,0.9984,0.9986,0.9969,0.9987,0.9991,0.9988,0.9982,0.9990,],
    'val_loss' : [0.7938,0.3327,0.8189,0.7278,0.0434,1.3791,0.2661,2.2710,0.0432,0.2656,0.3424,0.0988,1.0608,3.9390,0.2426,0.3649,0.0755,0.1208,0.3142,0.1148,0.0903,0.7003,0.1393,0.1330,0.0969,0.2812,1.2521,0.4130,0.1679,5.2185,0.0595,0.2633,1.1949,0.9794,0.0704,1.8634,10.6981,700.5900,0.0474,0.2461,],
    'val_accuracy' : [0.7404,0.8715,0.7394,0.8153,0.9870,0.7058,0.9762,0.7141,0.9851,0.9670,0.9838,0.9948,0.9265,0.9212,0.9918,0.9281,0.9912,0.9919,0.9941,0.9840,0.9889,0.8999,0.9681,0.9959,0.9968,0.9943,0.9588,0.9923,0.9981,0.9619,0.9975,0.9966,0.9890,0.9877,0.9895,0.9917,0.9217,0.5857,0.9978,0.9977,],
}

# %%
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ## after remove outlier

# %%
history = {
    'loss' : [0.4153,0.0926,0.0504,0.0472,0.0337,0.0279,0.0245,0.0180,0.0207,0.0195,0.0137,0.0224,0.0107,0.0084,0.0124,0.0102,0.0090,0.0102,0.0082,0.0074,0.0076,0.0090,0.0051,0.0075,0.0067,0.0045,0.0069,0.0061,0.0037,0.0053,0.0052,0.0020,0.0051,0.0042,0.0126,0.0046,0.0029,0.0059,0.0032,],
    'accuracy' : [0.8352,0.9670,0.9826,0.9833,0.9884,0.9902,0.9916,0.9937,0.9929,0.9935,0.9957,0.9926,0.9964,0.9970,0.9962,0.9965,0.9966,0.9967,0.9975,0.9974,0.9974,0.9971,0.9984,0.9976,0.9978,0.9983,0.9980,0.9981,0.9987,0.9982,0.9985,0.9993,0.9984,0.9986,0.9969,0.9987,0.9991,0.9982,0.9990,],
    'val_loss' : [0.7938,0.3327,0.8189,0.7278,0.0434,1.3791,0.2661,2.2710,0.0432,0.2656,0.3424,0.0988,1.0608,3.9390,0.2426,0.3649,0.0755,0.1208,0.3142,0.1148,0.0903,0.7003,0.1393,0.1330,0.0969,0.2812,1.2521,0.4130,0.1679,5.2185,0.0595,0.2633,1.1949,0.9794,0.0704,1.8634,10.6981,0.0474,0.2461,],
    'val_accuracy' : [0.7404,0.8715,0.7394,0.8153,0.9870,0.7058,0.9762,0.7141,0.9851,0.9670,0.9838,0.9948,0.9265,0.9212,0.9918,0.9281,0.9912,0.9919,0.9941,0.9840,0.9889,0.8999,0.9681,0.9959,0.9968,0.9943,0.9588,0.9923,0.9981,0.9619,0.9975,0.9966,0.9890,0.9877,0.9895,0.9917,0.9217,0.9978,0.9977,],
}

# %%
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
